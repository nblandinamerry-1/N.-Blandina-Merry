# %% [markdown]
# <a href="https://colab.research.google.com/github/nblandinamerry-1/N.-Blandina-Merry/blob/main/qmc1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-69d52569-dbcd-48c1-b07d-cd0db41aac93" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69d52569-dbcd-48c1-b07d-cd0db41aac93">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
# load excel file
data = pd.read_excel('AI for QCM')
# check data
print (data.head())
print (data.column)
print (data.info())
# Out:
#    Height (cm)  Weight (kg)
# 0          150           50
# 1          152           52
# 2          155           54
# 3          157           55
# 4          160           58
# Index(['Height (cm)', 'Weight (kg)'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Height (cm)  20 non-null     int64
#  1   Weight (kg)  20 non-null     int64
# dtypes: int64(2)
# memory usage: 452.0 bytes
# None

# %%
# input & output column
x = data [['Height (cm)']]
y = data [['Weight (kg)']]

# %%
# split the data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state=42)

# %%
# view training data
print ("x_train:\n", x_train)
print ("y_train:\n", y_train)
# Out:
# x_train:
#      Height (cm)
# 8           170
# 5           162
# 11          177
# 3           157
# 18          195
# 16          190
# 13          182
# 2           155
# 9           172
# 19          198
# 4           160
# 12          180
# 7           167
# 10          175
# 14          185
# 6           165
# y_train:
#      Weight (kg)
# 8            67
# 5            60
# 11           72
# 3            55
# 18           90
# 16           85
# 13           77
# 2            54
# 9            68
# 19           92
# 4            58
# 12           75
# 7            64
# 10           70
# 14           80
# 6            62

# %%
# view testing data

# %%
# view testing data
print ("x_test:\n", x_test)
print ("y_test:\n", y_test)
# Out:
# x_test:
#      Height (cm)
# 0           150
# 17          192
# 15          187
# 1           152
# y_test:
#      Weight (kg)
# 0            50
# 17           87
# 15           82
# 1            52

# %%
# train Regression Model(Linear Regression)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# testing and evaluation
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(x_test)
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R-squared Score:", r2_score(y_test, y_pred))
# Out:
# Mean Squared Error: 1.0355045277741066
# R-squared Score: 0.996356262932838

# %%
# predict new values
# (for x= 145)
new_data = pd.DataFrame({'Height (cm)': [145]})
prediction = model.predict(new_data)
print ("Predicted value:", prediction )
# Out:
# Predicted value: [[44.28011735]]
